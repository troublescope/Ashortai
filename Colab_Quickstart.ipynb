# %% [markdown]
# # 🎬 OpenSource Clipping - Colab Quickstart
#
# This notebook allows you to turn long YouTube videos into viral short-form clips using AI.
#
# ### 💡 Preparation:
# 1. **Enable GPU**: Go to `Runtime` -> `Change runtime type` -> select `T4 GPU`.
# 2. **API Key**: Get a free Gemini API Key from [Google AI Studio](https://aistudio.google.com/apikey).

# %% [markdown]
# ## 1️⃣ Step 1: Install Dependencies
# This will clone the project and install all necessary tools (FFmpeg, Whisper, etc.).

# %%
# @title Install Project
import os

print("⏳ Cleaning environment and cloning repo...")
# !rm -rf ./* ./.*
# !git clone https://github.com/NaufalRizqullah/opensource-clipping.git .

print("⏳ Installing FFmpeg and Python packages (takes ~1-2 mins)...")
# !apt-get -qq update && apt-get -qq install -y ffmpeg
# !pip install -q -r requirements.txt

print("\n✅ Setup Complete! Ready for Step 2.")

# %% [markdown]
# ## 2️⃣ Step 2: Configure & Run
# Fill in your details below and run the cell to start the clipping process.

# %%
# @title 🚀 Run Clipping Pipeline

GOOGLE_API_KEY = "" # @param {type:"string"}
VIDEO_URL = "https://www.youtube.com/watch?v=Dc4_aBFAYWE" # @param {type:"string"}
NUMBER_OF_CLIPS = 3 # @param {type:"slider", min:1, max:10, step:1}
OUTPUT_RATIO = "9:16" # @param ["9:16", "1:1", "16:9"]
FONT_STYLE = "HORMOZI" # @param ["HORMOZI", "STORYTELLER", "CINEMATIC", "DEFAULT"]

import os
os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY

if not GOOGLE_API_KEY:
    print("❌ ERROR: Please enter your GOOGLE_API_KEY first!")
else:
    # !python main.py \
        --url "{VIDEO_URL}" \
        --clips {NUMBER_OF_CLIPS} \
        --ratio "{OUTPUT_RATIO}" \
        --font-style "{FONT_STYLE}" \
        --whisper-compute-type "float32"

    print("\n✅ Process Finished! Check the 'outputs/' folder for your videos.")

# %% [markdown]
# ---
# ### 📂 How to download your videos:
# 1. Click the **Folder icon** on the left sidebar.
# 2. Open the `outputs` folder.
# 3. Right-click on any `.mp4` file and select **Download**.
